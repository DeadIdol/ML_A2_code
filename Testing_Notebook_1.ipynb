# %%
import zipfile
import os
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd

if not os.path.exists('data_labels_extraData.csv'):
    with zipfile.ZipFile('./Image_classification_data.zip', 'r') as zip_ref:
        zip_ref.extractall('./')
    print('Data extracted successfully')
else:
    print('Data previously extracted')

main_data = pd.read_csv('./data_labels_mainData.csv')
extra_data = pd.read_csv('./data_labels_extraData.csv')
print("Main data : {}, Extra Data: {}".format(main_data.shape, extra_data.shape))
# Out:
# Data previously extracted
# Main data : (9896, 6), Extra Data: (10384, 4)

# %%
# As there is an isCancerous column for both datasets
# We will join them for this model
data = pd.concat([extra_data, main_data], axis=0, ignore_index=True) # concatenating along rows
data = data.drop(columns=['cellTypeName', 'cellType']) # Drop unnecessary columns
# Split into train, test and val
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)
train_data, val_data = train_test_split(train_data, test_size=0.25, random_state=42)

print("Train data : {}, Val Data: {}, Test Data: {}".format(train_data.shape, val_data.shape, test_data.shape))
display(train_data)
# Out:
# Train data : (12168, 4), Val Data: (4056, 4), Test Data: (4056, 4)
#        InstanceID  patientID  ImageName  isCancerous
# 233         18792         63  18792.png            0
# 17678        3280         46   3280.png            1
# 2371         6956         71   6956.png            0
# 5032         2919         80   2919.png            1
# 9768        21702         92  21702.png            0
# ...           ...        ...        ...          ...
# 18424        3378         51   3378.png            0
# 1897         6656         69   6656.png            0
# 3995        10620         79  10620.png            0
# 6833         9608         86   9608.png            0
# 17480       18138         44  18138.png            0
#
# [12168 rows x 4 columns]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_data['isCancerous'] = train_data['isCancerous'].astype('str')
val_data['isCancerous'] = val_data['isCancerous'].astype('str')

train_datagen = ImageDataGenerator(data_format='channels_last')
val_datagen = ImageDataGenerator(data_format='channels_last')

batch_size = 32

train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_data,
        directory='./patch_images',
        x_col="ImageName",
        y_col="isCancerous",
        target_size=(27, 27),
        batch_size=batch_size,
        class_mode='binary')

validation_generator = val_datagen.flow_from_dataframe(
        dataframe=val_data,
        directory='./patch_images',
        x_col="ImageName",
        y_col="isCancerous",
        target_size=(27, 27),
        batch_size=batch_size,  
        class_mode='binary')
# Out:
# Found 12168 validated image filenames belonging to 2 classes.
# Found 4056 validated image filenames belonging to 2 classes.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv2D,
    MaxPooling2D,
    Flatten,
    Dense,
    Dropout,
    BatchNormalization
)

# Define input shape based on 27x27 RGB images
input_shape = (27, 27, 3)

# Build a simple base CNN model
model = Sequential([
    # First convolutional block
    Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=input_shape),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Second convolutional block
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Flatten and dense layers
    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    # Output layer for binary classification
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', tf.metrics.AUC(name='auc')]
)

# Display model summary
model.summary()
# Out:
# C:\Users\rohan\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 27, 27, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 27, 27, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 13, 13, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         295,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 315,457 (1.20 MB)
#  Trainable params: 315,009 (1.20 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
epochs = 50
history = model.fit(train_generator, validation_data=validation_generator, epochs=epochs)
# Out:
# C:\Users\rohan\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 190s 491ms/step - accuracy: 0.7810 - auc: 0.8528 - loss: 0.5310 - val_accuracy: 0.7458 - val_auc: 0.9069 - val_loss: 0.8642
# Epoch 2/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 27s 72ms/step - accuracy: 0.8738 - auc: 0.9336 - loss: 0.3097 - val_accuracy: 0.7505 - val_auc: 0.9424 - val_loss: 0.6729
# Epoch 3/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 30s 79ms/step - accuracy: 0.8831 - auc: 0.9385 - loss: 0.2969 - val_accuracy: 0.7436 - val_auc: 0.9330 - val_loss: 0.5868
# Epoch 4/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.8872 - auc: 0.9474 - loss: 0.2740 - val_accuracy: 0.8720 - val_auc: 0.9459 - val_loss: 0.3023
# Epoch 5/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 29s 76ms/step - accuracy: 0.8901 - auc: 0.9518 - loss: 0.2660 - val_accuracy: 0.8316 - val_auc: 0.9438 - val_loss: 0.3999
# Epoch 6/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - accuracy: 0.8938 - auc: 0.9523 - loss: 0.2625 - val_accuracy: 0.8839 - val_auc: 0.9569 - val_loss: 0.2703
# Epoch 7/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 30s 78ms/step - accuracy: 0.8922 - auc: 0.9521 - loss: 0.2645 - val_accuracy: 0.7335 - val_auc: 0.9425 - val_loss: 0.6118
# Epoch 8/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 26s 68ms/step - accuracy: 0.8907 - auc: 0.9524 - loss: 0.2620 - val_accuracy: 0.8955 - val_auc: 0.9538 - val_loss: 0.2586
# Epoch 9/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 31s 82ms/step - accuracy: 0.8902 - auc: 0.9518 - loss: 0.2619 - val_accuracy: 0.7557 - val_auc: 0.8371 - val_loss: 0.8076
# Epoch 10/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 25s 67ms/step - accuracy: 0.8956 - auc: 0.9565 - loss: 0.2504 - val_accuracy: 0.7219 - val_auc: 0.8176 - val_loss: 1.3449
# Epoch 11/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 30s 80ms/step - accuracy: 0.8981 - auc: 0.9552 - loss: 0.2521 - val_accuracy: 0.7776 - val_auc: 0.9376 - val_loss: 0.4689
# Epoch 12/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 30s 79ms/step - accuracy: 0.8993 - auc: 0.9578 - loss: 0.2456 - val_accuracy: 0.8333 - val_auc: 0.9526 - val_loss: 0.4055
# Epoch 13/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 32s 84ms/step - accuracy: 0.8961 - auc: 0.9574 - loss: 0.2489 - val_accuracy: 0.8301 - val_auc: 0.9429 - val_loss: 0.4325
# Epoch 14/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 25s 66ms/step - accuracy: 0.9103 - auc: 0.9643 - loss: 0.2256 - val_accuracy: 0.7355 - val_auc: 0.8155 - val_loss: 1.2477
# Epoch 15/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 25s 66ms/step - accuracy: 0.9017 - auc: 0.9602 - loss: 0.2388 - val_accuracy: 0.7429 - val_auc: 0.9566 - val_loss: 0.5276
# Epoch 16/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 37s 55ms/step - accuracy: 0.8975 - auc: 0.9588 - loss: 0.2462 - val_accuracy: 0.4524 - val_auc: 0.7954 - val_loss: 2.4520
# Epoch 17/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 30s 78ms/step - accuracy: 0.9022 - auc: 0.9599 - loss: 0.2414 - val_accuracy: 0.8373 - val_auc: 0.9198 - val_loss: 0.4178
# Epoch 18/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.9082 - auc: 0.9650 - loss: 0.2250 - val_accuracy: 0.8235 - val_auc: 0.9256 - val_loss: 0.4257
# Epoch 19/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - accuracy: 0.9077 - auc: 0.9647 - loss: 0.2272 - val_accuracy: 0.9053 - val_auc: 0.9631 - val_loss: 0.2449
# Epoch 20/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 27s 72ms/step - accuracy: 0.9066 - auc: 0.9657 - loss: 0.2234 - val_accuracy: 0.6516 - val_auc: 0.9284 - val_loss: 1.0705
# Epoch 21/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 27s 71ms/step - accuracy: 0.9048 - auc: 0.9648 - loss: 0.2250 - val_accuracy: 0.7983 - val_auc: 0.9529 - val_loss: 0.5383
# Epoch 22/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.9183 - auc: 0.9706 - loss: 0.2050 - val_accuracy: 0.8373 - val_auc: 0.9265 - val_loss: 0.4706
# Epoch 23/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 26s 68ms/step - accuracy: 0.9176 - auc: 0.9705 - loss: 0.2075 - val_accuracy: 0.6307 - val_auc: 0.9508 - val_loss: 1.0001
# Epoch 24/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 31s 81ms/step - accuracy: 0.9222 - auc: 0.9738 - loss: 0.1954 - val_accuracy: 0.8484 - val_auc: 0.9380 - val_loss: 0.4542
# Epoch 25/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - accuracy: 0.9191 - auc: 0.9725 - loss: 0.2009 - val_accuracy: 0.8979 - val_auc: 0.9616 - val_loss: 0.2653
# Epoch 26/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 43s 69ms/step - accuracy: 0.9159 - auc: 0.9719 - loss: 0.2020 - val_accuracy: 0.4332 - val_auc: 0.8728 - val_loss: 2.2677
# Epoch 27/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 31s 82ms/step - accuracy: 0.9232 - auc: 0.9740 - loss: 0.1924 - val_accuracy: 0.8923 - val_auc: 0.9624 - val_loss: 0.2728
# Epoch 28/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 29s 76ms/step - accuracy: 0.9156 - auc: 0.9717 - loss: 0.2028 - val_accuracy: 0.8333 - val_auc: 0.9548 - val_loss: 0.4140
# Epoch 29/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 26s 69ms/step - accuracy: 0.9217 - auc: 0.9745 - loss: 0.1924 - val_accuracy: 0.8499 - val_auc: 0.9282 - val_loss: 0.5166
# Epoch 30/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 32s 84ms/step - accuracy: 0.9255 - auc: 0.9759 - loss: 0.1872 - val_accuracy: 0.8393 - val_auc: 0.9303 - val_loss: 0.4836
# Epoch 31/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 27s 72ms/step - accuracy: 0.9292 - auc: 0.9776 - loss: 0.1799 - val_accuracy: 0.8274 - val_auc: 0.8957 - val_loss: 0.5584
# Epoch 32/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 29s 75ms/step - accuracy: 0.9329 - auc: 0.9791 - loss: 0.1733 - val_accuracy: 0.8861 - val_auc: 0.9532 - val_loss: 0.2868
# Epoch 33/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 26s 67ms/step - accuracy: 0.9349 - auc: 0.9787 - loss: 0.1732 - val_accuracy: 0.8176 - val_auc: 0.9032 - val_loss: 0.6076
# Epoch 34/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 34s 88ms/step - accuracy: 0.9300 - auc: 0.9781 - loss: 0.1776 - val_accuracy: 0.9034 - val_auc: 0.9608 - val_loss: 0.2520
# Epoch 35/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 26s 68ms/step - accuracy: 0.9392 - auc: 0.9822 - loss: 0.1589 - val_accuracy: 0.8422 - val_auc: 0.9330 - val_loss: 0.4692
# Epoch 36/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 31s 81ms/step - accuracy: 0.9329 - auc: 0.9816 - loss: 0.1639 - val_accuracy: 0.8531 - val_auc: 0.9315 - val_loss: 0.5041
# Epoch 37/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 26s 69ms/step - accuracy: 0.9414 - auc: 0.9851 - loss: 0.1482 - val_accuracy: 0.8102 - val_auc: 0.8845 - val_loss: 0.8460
# Epoch 38/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 31s 81ms/step - accuracy: 0.9399 - auc: 0.9838 - loss: 0.1529 - val_accuracy: 0.7069 - val_auc: 0.7251 - val_loss: 2.0733
# Epoch 39/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 27s 70ms/step - accuracy: 0.9358 - auc: 0.9815 - loss: 0.1621 - val_accuracy: 0.8925 - val_auc: 0.9549 - val_loss: 0.2911
# Epoch 40/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 31s 81ms/step - accuracy: 0.9400 - auc: 0.9851 - loss: 0.1468 - val_accuracy: 0.9061 - val_auc: 0.9594 - val_loss: 0.2735
# Epoch 41/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 27s 71ms/step - accuracy: 0.9435 - auc: 0.9852 - loss: 0.1465 - val_accuracy: 0.8686 - val_auc: 0.9602 - val_loss: 0.3518
# Epoch 42/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 33s 86ms/step - accuracy: 0.9431 - auc: 0.9854 - loss: 0.1450 - val_accuracy: 0.8895 - val_auc: 0.9483 - val_loss: 0.3824
# Epoch 43/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - accuracy: 0.9441 - auc: 0.9862 - loss: 0.1408 - val_accuracy: 0.8050 - val_auc: 0.8639 - val_loss: 0.9230
# Epoch 44/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 31s 82ms/step - accuracy: 0.9454 - auc: 0.9866 - loss: 0.1411 - val_accuracy: 0.8908 - val_auc: 0.9578 - val_loss: 0.2746
# Epoch 45/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 27s 71ms/step - accuracy: 0.9422 - auc: 0.9869 - loss: 0.1396 - val_accuracy: 0.8955 - val_auc: 0.9562 - val_loss: 0.3225
# Epoch 46/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 32s 84ms/step - accuracy: 0.9425 - auc: 0.9856 - loss: 0.1458 - val_accuracy: 0.8516 - val_auc: 0.8940 - val_loss: 0.5634
# Epoch 47/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 29s 77ms/step - accuracy: 0.9449 - auc: 0.9859 - loss: 0.1437 - val_accuracy: 0.8817 - val_auc: 0.9525 - val_loss: 0.2909
# Epoch 48/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 32s 84ms/step - accuracy: 0.9453 - auc: 0.9881 - loss: 0.1316 - val_accuracy: 0.7616 - val_auc: 0.8224 - val_loss: 1.5220
# Epoch 49/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 28s 74ms/step - accuracy: 0.9500 - auc: 0.9889 - loss: 0.1258 - val_accuracy: 0.9098 - val_auc: 0.9624 - val_loss: 0.2499
# Epoch 50/50
# 381/381 ━━━━━━━━━━━━━━━━━━━━ 32s 85ms/step - accuracy: 0.9495 - auc: 0.9886 - loss: 0.1291 - val_accuracy: 0.8627 - val_auc: 0.9279 - val_loss: 0.3892

# %%
import matplotlib.pyplot as plt


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
